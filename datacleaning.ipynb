# %%
#Importing Libraries

import pandas as pd
import numpy as np

# %%
#Reading file

sales = pd.read_csv("messy_sales.csv")

# %%
#Reading first 5 rows

sales.head()
# Out:
#    order_id  customer_name    product     category  quantity    price  \
# 0         1   Alice Davis       Mouse  Electronics       1.0  1488.95
# 1         2  Patel Davis      Monitor  electronics       1.0   242.74
# 2         3   Bob Johnson    Monitor?  Electronics       1.0  1482.75
# 3         4  Patel Brown       Laptop     hardware       2.0  1466.15
# 4         5    Patel Davis  iPhone 14  ELECTRONICS       NaN  1192.79
#
#    total_amount        date region     status
# 0          0.00  05-09-2024  North     Active
# 1       1260.16  07/21/2024  North  completed
# 2           NaN  10-16-2024  South        NaN
# 3       2958.81  01/07/2024  East   Completed
# 4       2466.13  09-27-2024  North     Active

# %%
#Reading last 5 rows

sales.tail()
# Out:
#      order_id  customer_name   product     category  quantity        price  \
# 995       996    Mary Smith     Laptop  Electronics       3.0  1091.870000
# 996       997     Mary Smith   Monitor     hardware       1.0   190.740000
# 997       998   Alice Brown     Laptop  ELECTRONICS       2.0   461.130000
# 998       999  John Wilson    Keyboard    Hardware        1.0   803.380000
# 999      1000    John Smith      Mouse     hardware       1.0   850.980716
#
#      total_amount        date region     status
# 995           NaN  2024-02-27   EAST  Completed
# 996           NaN  2024/11/22   West    Pending
# 997       2403.08  03/24/2024   EAST        NaN
# 998           NaN  03-01-2024   EAST        NaN
# 999           NaN  2024/11/02   West        NaN

# %%
# getting information about sales data

sales.info()
sales.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_name  1000 non-null   object
#  2   product        1000 non-null   object
#  3   category       1000 non-null   object
#  4   quantity       948 non-null    float64
#  5   price          966 non-null    float64
#  6   total_amount   686 non-null    float64
#  7   date           1000 non-null   object
#  8   region         1000 non-null   object
#  9   status         679 non-null    object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 78.3+ KB
#           order_id    quantity        price  total_amount
# count  1000.000000  948.000000   966.000000    686.000000
# mean    500.500000    1.618143   749.387292   1107.766883
# std     288.819436    0.916681   427.013552   1163.177794
# min       1.000000   -1.000000    10.050000      0.000000
# 25%     250.750000    1.000000   377.857500      3.032500
# 50%     500.500000    2.000000   755.640000    788.635000
# 75%     750.250000    2.000000  1114.150000   1767.300000
# max    1000.000000    3.000000  1496.646590   4431.050000

# %%
#Finding count of null values by columns

sales.isna().sum()
# Out:
# order_id           0
# customer_name      0
# product            0
# category           0
# quantity          52
# price             34
# total_amount     314
# date               0
# region             0
# status           321
# dtype: int64

# %%
sales['customer_name'].unique()
# Out:
# array(['Alice Davis', 'Patel Davis', 'Bob Johnson', 'Patel Brown',
#        'Alice Brown', 'Sarah Davis', 'Mary Wilson?', 'Sarah Johnson',
#        'Alice Davis***', 'John Wilson', 'Mary Davis', 'Alice Smith',
#        'John Brown', 'Patel Johnson', 'Alice Wilson', 'Sarah Brown',
#        'Bob Brown', 'Bob Smith', 'Mary Wilson', 'Mary Smith',
#        'Patel Smith', 'Alice Johnson', 'Mary Johnson', 'Sarah Wilson',
#        'John Davis', 'Bob Davis', 'John Smith', 'Patel Wilson',
#        'Mary Brown', 'John Johnson', 'Bob Wilson', 'Bob Wilson  ?',
#        'Sarah Smith', 'John Brown***', 'Mary Johnson?', 'Patel Wilson?',
#        'Bob Brown ?', 'Bob Davis***', 'Patel Davis***', 'Bob Johnson ?',
#        'Patel Johnson  ***', 'Alice Brown  ?', 'Patel Wilson ***',
#        'John Smith  ?', 'Bob Wilson ***', 'Bob Smith?', 'Mary Wilson  ?',
#        'Bob Johnson***', 'Sarah Wilson ?', 'John Johnson  ?',
#        'Sarah Brown***', 'Bob Smith  ***', 'Mary Wilson ***',
#        'Sarah Davis ?'], dtype=object)

# %%
#Removing extra space from customer name
sales['customer_name'] = sales['customer_name'].str.strip()
sales
# Out:
#      order_id customer_name    product     category  quantity        price  \
# 0           1   Alice Davis      Mouse  Electronics       1.0  1488.950000
# 1           2   Patel Davis    Monitor  electronics       1.0   242.740000
# 2           3   Bob Johnson   Monitor?  Electronics       1.0  1482.750000
# 3           4   Patel Brown     Laptop     hardware       2.0  1466.150000
# 4           5   Patel Davis  iPhone 14  ELECTRONICS       NaN  1192.790000
# ..        ...           ...        ...          ...       ...          ...
# 995       996    Mary Smith     Laptop  Electronics       3.0  1091.870000
# 996       997    Mary Smith    Monitor     hardware       1.0   190.740000
# 997       998   Alice Brown     Laptop  ELECTRONICS       2.0   461.130000
# 998       999   John Wilson   Keyboard    Hardware        1.0   803.380000
# 999      1000    John Smith      Mouse     hardware       1.0   850.980716
#
#      total_amount        date region     status
# 0            0.00  05-09-2024  North     Active
# 1         1260.16  07/21/2024  North  completed
# 2             NaN  10-16-2024  South        NaN
# 3         2958.81  01/07/2024  East   Completed
# 4         2466.13  09-27-2024  North     Active
# ..            ...         ...    ...        ...
# 995           NaN  2024-02-27   EAST  Completed
# 996           NaN  2024/11/22   West    Pending
# 997       2403.08  03/24/2024   EAST        NaN
# 998           NaN  03-01-2024   EAST        NaN
# 999           NaN  2024/11/02   West        NaN
#
# [1000 rows x 10 columns]

# %%
# Out:
# np.int64(0)
